# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import load_dataset

# %%
! dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CB9-E181
#
#  Directory of C:\Mod3-Matplotlib and Seaborn\datas
#
# 08/22/2023  08:24 PM    <DIR>          .
# 08/22/2023  08:24 PM    <DIR>          ..
# 08/21/2023  08:36 PM    <DIR>          .ipynb_checkpoints
# 08/21/2023  08:30 PM           322,026 airlines.csv
# 08/22/2023  09:08 AM               361 anagrams.csv
# 08/22/2023  09:09 AM               556 anscombe.csv
# 08/22/2023  09:09 AM             1,198 attention.csv
# 08/22/2023  09:12 AM         1,075,911 brain_networks.csv
# 08/17/2023  10:58 AM               111 csv_mindex.csv
# 08/17/2023  10:58 AM                59 demo1.csv
# 08/17/2023  10:58 AM            10,545 demo1.xlsx
# 08/17/2023  10:58 AM                43 demo2.csv
# 08/17/2023  10:58 AM               169 demo3.csv
# 08/17/2023  10:58 AM               170 demo3.txt
# 08/17/2023  10:58 AM               169 demo4.csv
# 08/17/2023  10:58 AM                78 demo5.csv
# ...

# %% [markdown]
# ### diamond dataset

# %%
diamond = pd.read_csv("diamonds.csv",index_col="Unnamed: 0")
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %% [markdown]
# ###### seaborn

# %% [markdown]
# ###### numerical plots

# %%
sns.relplot(data=diamond,x='depth',y='price')
plt.title("depth Vs price of diamond")
plt.grid()
plt.show()

# %%
sns.relplot(data=diamond,x='depth',y='price',style="color",color="green")
plt.title("depth Vs price of diamond")
plt.grid()
plt.show()

# %%
sns.relplot(data=diamond,x='depth',y='price',style="color",color="green",kind='line')
plt.title("depth Vs price of diamond")
plt.grid()
plt.show()

# %%
diamond["color"].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
airlines = pd.read_csv("airlines.csv",index_col="Airline ID")
airlines
# Out:
#                                                     Name              Alias  \
# Airline ID
# -1                                               Unknown                 \N
#  1                                        Private flight                 \N
#  2                                           135 Airways                 \N
#  3                                         1Time Airline                 \N
#  4          2 Sqn No 1 Elementary Flying Training School                 \N
# ...                                                  ...                ...
#  21248                                       GX Airlines                NaN
#  21251                            Lynx Aviation (L3/SSX)                NaN
#  21268                                   Jetgo Australia                NaN
#  21270                                      Air Carnival                NaN
#  21317                                     Svyaz Rossiya  Russian Commuter
#
# ...

# %%
airlines.columns
# Out:
# Index(['Name', 'Alias', 'IATA', 'ICAO', 'Callsign', 'Country', 'Active'], dtype='object')

# %%
! dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CB9-E181
#
#  Directory of C:\Mod3-Matplotlib and Seaborn\datas
#
# 08/22/2023  09:19 AM    <DIR>          .
# 08/22/2023  09:19 AM    <DIR>          ..
# 08/21/2023  08:36 PM    <DIR>          .ipynb_checkpoints
# 08/21/2023  08:30 PM           322,026 airlines.csv
# 08/17/2023  10:58 AM               111 csv_mindex.csv
# 08/17/2023  10:58 AM                59 demo1.csv
# 08/17/2023  10:58 AM            10,545 demo1.xlsx
# 08/17/2023  10:58 AM                43 demo2.csv
# 08/17/2023  10:58 AM               169 demo3.csv
# 08/17/2023  10:58 AM               170 demo3.txt
# 08/17/2023  10:58 AM               169 demo4.csv
# 08/17/2023  10:58 AM                78 demo5.csv
# 08/17/2023  10:58 AM           626,863 demo6.csv
# 08/17/2023  10:58 AM                36 demo7.csv
# 08/17/2023  09:04 PM            23,171 demofigsave.png
# 08/17/2023  10:58 AM             6,189 demo_file.xlsx
# ...

# %% [markdown]
# # TASK

# %%
salary = pd.read_csv("ds_salaries.csv")
salary
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# 5             5       2020               EN              FT
# 6             6       2020               SE              FT
# 7             7       2020               MI              FT
# 8             8       2020               MI              FT
# 9             9       2020               SE              FT
# 10           10       2020               EN              FT
# 11           11       2020               MI              FT
# 12           12       2020               EN              FT
# 13           13       2020               MI              FT
# 14           14       2020               MI              FT
# ...

# %%
ds = salary.rename({"Unnamed: 0":"ID"},axis=1)
ds
# Out:
#       ID  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# 5      5       2020               EN              FT
# 6      6       2020               SE              FT
# 7      7       2020               MI              FT
# 8      8       2020               MI              FT
# 9      9       2020               SE              FT
# 10    10       2020               EN              FT
# 11    11       2020               MI              FT
# 12    12       2020               EN              FT
# 13    13       2020               MI              FT
# 14    14       2020               MI              FT
# 15    15       2020               MI              FT
# 16    16       2020               EN              FT
# ...

# %%
ds.columns
# Out:
# Index(['ID', 'work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
ds.shape
# Out:
# (607, 12)

# %%
# there are 607 rows and 12 columns in the given dataset

# %%
ds["work_year"].value_counts()
# Out:
# 2022    318
# 2021    217
# 2020     72
# Name: work_year, dtype: int64

# %%
ds["experience_level"].value_counts()
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
ds["employment_type"].value_counts()
# Out:
# FT    588
# PT     10
# CT      5
# FL      4
# Name: employment_type, dtype: int64

# %%
ds["job_title"].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
ds["salary"].value_counts()
# Out:
# 100000     18
# 80000      18
# 120000     15
# 60000      15
# 150000     14
# 50000      13
# 75000      11
# 130000     11
# 70000      10
# 200000     10
# 90000      10
# 160000      9
# 140000      9
# 135000      9
# 170000      8
# 40000       8
# 110000      8
# 180000      8
# 65000       7
# 85000       7
# 45000       6
# 20000       6
# 55000       6
# 115000      6
# 30000       5
# 210000      5
# 90320       5
# 105000      5
# 125000      4
# 112900      4
#            ..
# 99360       1
# 146000      1
# 116000      1
# 242000      1
# 165220      1
# 2100000     1
# 108000      1
# 22000       1
# 32000       1
# 74000       1
# 152000      1
# 21844       1
# 18000       1
# 120500      1
# 9272        1
# 1799997     1
# 4000000     1
# 195000      1
# 69600       1
# 31000       1
# 435000      1
# 2500000     1
# 40900       1
# 416000      1
# 1200000     1
# 256000      1
# 39600       1
# 1335000     1
# 52500       1
# 129000      1
# ...

# %%
ds["salary_currency"].value_counts()
# Out:
# USD    398
# EUR     95
# GBP     44
# INR     27
# CAD     18
# JPY      3
# PLN      3
# TRY      3
# CNY      2
# MXN      2
# HUF      2
# DKK      2
# SGD      2
# BRL      2
# AUD      2
# CLP      1
# CHF      1
# Name: salary_currency, dtype: int64

# %%
ds["salary_in_usd"].value_counts()
# Out:
# 100000    15
# 120000    12
# 150000    12
# 200000    10
# 135000     9
# 170000     8
# 160000     8
# 140000     8
# 80000      8
# 130000     8
# 90000      6
# 180000     5
# 50000      5
# 105000     5
# 110000     5
# 20000      5
# 210000     5
# 115000     5
# 90320      5
# 60000      5
# 75000      4
# 87932      4
# 165000     4
# 78526      4
# 112900     4
# 85000      4
# 220000     3
# 12000      3
# 54957      3
# 230000     3
#           ..
# 168000     1
# 40038      1
# 62649      1
# 82744      1
# 82500      1
# 240000     1
# 77364      1
# 63711      1
# 24000      1
# 2859       1
# 81000      1
# 56738      1
# 147000     1
# 12901      1
# 37825      1
# 195000     1
# 61467      1
# 54094      1
# 24342      1
# 9272       1
# 96113      1
# 5679       1
# 18000      1
# 21844      1
# 152000     1
# 74000      1
# 61896      1
# 26005      1
# 22611      1
# 129000     1
# Name: salary_in_usd, Length: 369, dtype: int64

# %%
ds["employee_residence"].value_counts()
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PT      6
# BR      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AE      3
# AT      3
# VN      3
# TR      3
# AU      3
# RO      2
# BE      2
# SG      2
# SI      2
# DK      2
# HU      2
# NG      2
# MX      2
# BO      1
# MY      1
# TN      1
# IE      1
# DZ      1
# AR      1
# CZ      1
# JE      1
# LU      1
# PR      1
# RS      1
# EE      1
# CL      1
# HK      1
# KE      1
# MD      1
# CO      1
# IR      1
# CN      1
# MT      1
# UA      1
# IQ      1
# HN      1
# BG      1
# HR      1
# PH      1
# NZ      1
# CH      1
# Name: employee_residence, dtype: int64

# %%
ds["remote_ratio"].value_counts()
# Out:
# 100    381
# 0      127
# 50      99
# Name: remote_ratio, dtype: int64

# %%
ds["company_location"].value_counts()
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: company_location, dtype: int64

# %%
ds["company_size"].value_counts()
# Out:
# M    326
# L    198
# S     83
# Name: company_size, dtype: int64

# %% [markdown]
# ### ? Job Title, Location and Salary wise analysis

# %%
ds["job_title"].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %%
pd.set_option("display.min_rows",607)
salary_data = ds.loc[:,:]
salary_data
# Out:
#       ID  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# 5      5       2020               EN              FT
# 6      6       2020               SE              FT
# 7      7       2020               MI              FT
# 8      8       2020               MI              FT
# 9      9       2020               SE              FT
# 10    10       2020               EN              FT
# 11    11       2020               MI              FT
# 12    12       2020               EN              FT
# 13    13       2020               MI              FT
# 14    14       2020               MI              FT
# 15    15       2020               MI              FT
# 16    16       2020               EN              FT
# ...

# %%
pd.set_option("display.min_rows",607)
salary_data1 = ds.loc[:,["job_title","company_location","salary","employee_residence"]]
salary_data1
# Out:
#                       job_title company_location    salary employee_residence
# 0                Data Scientist               DE     70000                 DE
# 1    Machine Learning Scientist               JP    260000                 JP
# 2             Big Data Engineer               GB     85000                 GB
# 3          Product Data Analyst               HN     20000                 HN
# 4     Machine Learning Engineer               US    150000                 US
# 5                  Data Analyst               US     72000                 US
# 6           Lead Data Scientist               US    190000                 US
# 7                Data Scientist               HU  11000000                 HU
# 8         Business Data Analyst               US    135000                 US
# 9            Lead Data Engineer               NZ    125000                 NZ
# 10               Data Scientist               FR     45000                 FR
# ...

# %%
ds.isnull().sum().value_counts()
# Out:
# 0    12
# dtype: int64

# %% [markdown]
# ### job_group

# %%
job_group.get_group("Data Scientist").value_counts()
# Out:
# ID   work_year  experience_level  employment_type  job_title       salary   salary_currency  salary_in_usd  employee_residence  remote_ratio  company_location  company_size
# 0    2020       MI                FT               Data Scientist  70000    EUR              79833          DE                  0             DE                L               1
# 459  2022       MI                FT               Data Scientist  2400000  INR              31615          IN                  100           IN                L               1
# 411  2022       MI                FT               Data Scientist  35000    GBP              45807          GB                  0             GB                M               1
# 416  2022       SE                FT               Data Scientist  260000   USD              260000         US                  100           US                M               1
# ...

# %%
job_group.get_group("Data Scientist").value_counts()
# Out:
# ID   work_year  experience_level  employment_type  job_title       salary   salary_currency  salary_in_usd  employee_residence  remote_ratio  company_location  company_size
# 0    2020       MI                FT               Data Scientist  70000    EUR              79833          DE                  0             DE                L               1
# 459  2022       MI                FT               Data Scientist  2400000  INR              31615          IN                  100           IN                L               1
# 411  2022       MI                FT               Data Scientist  35000    GBP              45807          GB                  0             GB                M               1
# 416  2022       SE                FT               Data Scientist  260000   USD              260000         US                  100           US                M               1
# ...

# %%
job_group = ds.groupby("job_title")

# %%
pd.set_option('display.min_rows',98)
job_group["work_year"].value_counts()
# Out:
# job_title                                 work_year
# 3D Computer Vision Researcher             2021          1
# AI Scientist                              2021          4
#                                           2022          2
#                                           2020          1
# Analytics Engineer                        2022          4
# Applied Data Scientist                    2022          3
#                                           2021          2
# Applied Machine Learning Scientist        2021          2
#                                           2022          2
# BI Data Analyst                           2021          5
#                                           2020          1
# Big Data Architect                        2021          1
# Big Data Engineer                         2021          5
#                                           2020          3
# Business Data Analyst                     2020          2
# ...

# %%
ds["job_title"].str.contains("Data").value_counts()
# Out:
# True     499
# False    108
# Name: job_title, dtype: int64

# %% [markdown]
# ##### plot

# %%
year_group=ds.groupby("work_year")

# %%
sns.relplot(data=salary,x="work_year",y="salary",style="job_title",color="red")
plt.title("Job Vs work_year")
plt.xlabel("work_year")
plt.ylabel("salary")
plt.xticks(rotation=95)
plt.show()

# %%
plt.(data=salary,x="work_year",y="salary",style="job_title",color="red")
plt.title("Job Vs work_year")
plt.xlabel("work_year")
plt.ylabel("salary")
plt.xticks(rotation=95)
plt.show()
# Out:
#   Cell In[67], line 1
#     plt.(data=salary,x="work_year",y="salary",style="job_title",color="red")
#         ^
# SyntaxError: invalid syntax

# %%
salary["work_year"].value_counts()
# Out:
# 2022    318
# 2021    217
# 2020     72
# Name: work_year, dtype: int64

# %% [markdown]
# ### year_group

# %%
year_group = salary.groupby("work_year")

# %%
year2020 = year_group.get_group(2020)
year2021 = year_group.get_group(2021)
year2022 = year_group.get_group(2022)

# %% [markdown]
# # 2020

# %%
sns.relplot(data=year2020,x="salary",y="job_title")
plt.title("2020 ds salary")
plt.xlabel("salary")
plt.ylabel("job")
pl
plt.show()

# %%
year_group[["job_title","company_location"]].get_group(2020).value_counts().sort_index()
# Out:
# job_title                                 company_location
# AI Scientist                              DK                  1
# BI Data Analyst                           US                  1
# Big Data Engineer                         GB                  2
#                                           US                  1
# Business Data Analyst                     US                  2
# Computer Vision Engineer                  US                  1
# Data Analyst                              FR                  1
#                                           IN                  1
#                                           NG                  1
#                                           PK                  1
#                                           US                  3
# Data Engineer                             AT                  1
#                                           DE                  1
#                                           FR                  1
# ...

# %%
year2020.max()
# Out:
# Unnamed: 0                            71
# work_year                           2020
# experience_level                      SE
# employment_type                       PT
# job_title             Research Scientist
# salary                          11000000
# salary_currency                      USD
# salary_in_usd                     450000
# employee_residence                    US
# remote_ratio                         100
# company_location                      US
# company_size                           S
# dtype: object

# %%
year2020.min()
# Out:
# Unnamed: 0                       0
# work_year                     2020
# experience_level                EN
# employment_type                 CT
# job_title             AI Scientist
# salary                        8000
# salary_currency                CAD
# salary_in_usd                 5707
# employee_residence              AE
# remote_ratio                     0
# company_location                AE
# company_size                     L
# dtype: object

# %% [markdown]
# # 2021

# %%
sns.relplot(data=year2021,x="salary",y="job_title")
plt.title("2021 ds salary")
plt.xlabel("salary")
plt.ylabel("job")

plt.show()

# %%
year_group[["job_title","company_location"]].get_group(2021).value_counts().sort_index()
# Out:
# job_title                                 company_location
# 3D Computer Vision Researcher             IN                   1
# AI Scientist                              AS                   1
#                                           ES                   1
#                                           US                   2
# Applied Data Scientist                    CA                   1
#                                           GB                   1
# Applied Machine Learning Scientist        US                   2
# BI Data Analyst                           KE                   1
#                                           US                   4
# Big Data Architect                        CA                   1
# Big Data Engineer                         CH                   1
#                                           IN                   2
#                                           MD                   1
#                                           RO                   1
# ...

# %%
year2021.max()
# Out:
# Unnamed: 0                             288
# work_year                             2021
# experience_level                        SE
# employment_type                         PT
# job_title             Staff Data Scientist
# salary                            30400000
# salary_currency                        USD
# salary_in_usd                       600000
# employee_residence                      VN
# remote_ratio                           100
# company_location                        VN
# company_size                             S
# dtype: object

# %%
year2021.min()
# Out:
# Unnamed: 0                                       72
# work_year                                      2021
# experience_level                                 EN
# employment_type                                  CT
# job_title             3D Computer Vision Researcher
# salary                                         4000
# salary_currency                                 BRL
# salary_in_usd                                  2859
# employee_residence                               BE
# remote_ratio                                      0
# company_location                                 AS
# company_size                                      L
# dtype: object

# %% [markdown]
# # 2022

# %%
sns.relplot(data=year2022,x="salary",y="job_title",style="company_location")
plt.title("2022 ds salary")
plt.xlabel("salary")
plt.ylabel("job")
plt.show()

# %%
year_group[["job_title","company_location"]].get_group(2022).value_counts().sort_index()
# Out:
# job_title                                 company_location
# AI Scientist                              US                   2
# Analytics Engineer                        US                   4
# Applied Data Scientist                    US                   3
# Applied Machine Learning Scientist        CZ                   1
#                                           US                   1
# Business Data Analyst                     CA                   1
#                                           IN                   1
# Computer Vision Engineer                  LU                   1
#                                           US                   1
# Computer Vision Software Engineer         AU                   1
# Data Analyst                              CA                   8
#                                           ES                   2
#                                           GB                   4
#                                           GR                   3
# ...

# %%
year2022.max()
# Out:
# work_year                           2022
# experience_level                      SE
# employment_type                       PT
# job_title             Research Scientist
# salary                           6000000
# salary_currency                      USD
# salary_in_usd                     405000
# employee_residence                    US
# remote_ratio                         100
# company_location                      US
# company_size                           S
# dtype: object

# %%
year2022.min()
# Out:
# Unnamed: 0                     289
# work_year                     2022
# experience_level                EN
# employment_type                 CT
# job_title             AI Scientist
# salary                       10000
# salary_currency                AUD
# salary_in_usd                10000
# employee_residence              AE
# remote_ratio                     0
# company_location                AE
# company_size                     L
# dtype: object

# %%
x=[salary["work_year"]]
y=[salary["salary"]]
plt.bar(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 3
#       1 x=[salary["work_year"]]
#       2 y=[salary["salary"]]
# ----> 3 plt.bar(x,y)
#       4 plt.show()
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\pyplot.py:2412, in bar(x, height, width, bottom, align, data, **kwargs)
#    2408 @_copy_docstring_and_deprecators(Axes.bar)
#    2409 def bar(
#    2410         x, height, width=0.8, bottom=None, *, align='center',
#    2411         data=None, **kwargs):
# -> 2412     return gca().bar(
#    2413         x, height, width=width, bottom=bottom, align=align,
#    2414         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
# ...

# %%
plt.plot(salary["job_title"]==,salary["salary"])

# %%
ds.columns
# Out:
# Index(['ID', 'work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ###### plot

# %%
plt.plot(ds["job_title"],ds["salary"],label="job and salary")
plt.title("salary Vs different job")
plt.xlabel("job_title ")
plt.ylabel("salary")
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %%
plt.scatter(ds["job_title"],ds["salary"],label="job and salary",color="red",linestyle=":",marker="*",s=45)
plt.title("salary Vs different job")
plt.xlabel("job_title ")
plt.ylabel("salary")
plt.legend()
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
ds["salary"].max()
# Out:
# 30400000

# %%
ds["salary"].min()
# Out:
# 4000

# %%
plt.bar(ds["job_title"],ds["salary"],label="job and salary",width=2.5,color="green",linestyle=":")
plt.title("salary Vs different job")
plt.xlabel("job_title ")
plt.ylabel("salary")
plt.legend()
plt.xticks(rotation=90)

plt.show()

# %%
plt.bar(ds["job_title"],ds["company_location"],label="job and salary",width=2.5,color="green",linestyle=":")
plt.title("salary Vs different job")
plt.xlabel("job_title ")
plt.ylabel("company_location")
plt.legend()
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %%
salary = pd.read_csv("ds_salaries.csv")
ds =  salary.rename({"Unnamed: 0":"ID"},axis=1)
plt.hist(ds["job_title"],histtype="stepfilled",bins=100,color="yellow",edgecolor="green")
plt.title("job")
plt.xlabel("job_title ")
plt.ylabel("no:of workers")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.hist(ds["company_location"],histtype="stepfilled",bins=100,color="yellow",edgecolor="green")
plt.title("company_location")
plt.xlabel("company_location ")
plt.ylabel("no:of workers")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.hist(ds["salary"],histtype="step",bins=10000,edgecolor="green")
plt.title("salary")
plt.xlabel("salary")
plt.ylabel("no:of workers")
plt.xticks(rotation=90)

plt.show()

# %%
ds["salary"].max()
# Out:
# 30400000

# %%
plt.yticks(rotation=0)
plt.subplot(2,1,1)
plt.plot(ds["salary"],ds["job_title"])
plt.yticks(rotation=0)
plt.subplot(2,1,2)
plt.plot(ds["salary"],ds["company_location"])

# %%
sns.relplot(data=ds,x="job_title",y="salary",style="work_year")
plt.title("ds salary")
plt.xlabel("job")
plt.ylabel("salary")
plt.xticks(rotation=90)
plt.show()

# %%
sns.relplot(data=ds,x="job_title",y="salary",style="salary_in_usd")
plt.title("ds salary")
plt.xlabel("salary")
plt.ylabel("job")
plt.xticks(rotation=90)
plt.show()

# %%
sns.relplot(data=ds,x="job_title",y="salary",style="employment_type")
plt.title("ds salary")
plt.xlabel("job")
plt.ylabel("salary")
plt.xticks(rotation=90)
plt.show()

# %%
 ds["job_title"].str.contains("Scientist").value_counts()
# Out:
# False    413
# True     194
# Name: job_title, dtype: int64

# %%
ds["job_title"].str.contains("Data").value_counts()
# Out:
# True     499
# False    108
# Name: job_title, dtype: int64

# %%
ds["job_title"].str.contains("Computer").value_counts()
# Out:
# False    597
# True      10
# Name: job_title, dtype: int64

# %%
ds["job_title"].str.contains("Machine").value_counts()
# Out:
# False    545
# True      62
# Name: job_title, dtype: int64

# %%
ds["job_title"].str.contains("Engineer").value_counts()
# Out:
# False    377
# True     230
# Name: job_title, dtype: int64

# %%
ds["job_title"].str.contains("Analytics").value_counts()
# Out:
# False    591
# True      16
# Name: job_title, dtype: int64
